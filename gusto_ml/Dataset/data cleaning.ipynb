# %%
import pandas as pd

pd.set_option('display.max_columns', None)

# %%
tree_census = pd.read_csv('Gusto Dataset.csv')
tree_census
# Out:
#        Unnamed: 0                                              Title  \
# 0               0  Miso-Butter Roast Chicken With Acorn Squash Pa...
# 1               1                    Crispy Salt and Pepper Potatoes
# 2               2                        Thanksgiving Mac and Cheese
# 3               3                 Italian Sausage and Bread Stuffing
# 4               4                                       Newton's Law
# ...           ...                                                ...
# 13496       13496                               Brownie Pudding Cake
# 13497       13497  Israeli Couscous with Roasted Butternut Squash...
# 13498       13498  Rice with Soy-Glazed Bonito Flakes and Sesame ...
# 13499       13499                                        Spanakopita
# 13500       13500  Mexican Poblano, Spinach, and Black Bean "Lasa...
#
#                                              Ingredients  \
# 0      ['1 (3½–4-lb.) whole chicken', '2¾ tsp. kosher...
# ...

# %%
tree_census.columns
# Out:
# Index(['Unnamed: 0', 'Title', 'Ingredients', 'Instructions', 'Image_Name',
#        'Cleaned_Ingredients'],
#       dtype='object')

# %%
col1 = tree_census['Ingredients']
col2 = tree_census['Cleaned_Ingredients']

diff = col1.compare(col2)

print(diff)
# Out:
#                                                     self  \
# 0      ['1 (3½–4-lb.) whole chicken', '2¾ tsp. kosher...
# 6      ['3 oz. Grand Marnier', '1 oz. Amaro Averna', ...
# 8      ['¾ cup assorted dals (such as chana dal, moon...
# 9      ['1 (14.5-ounce) can basic lentil soup, like A...
# 13     ['8 anchovies, mashed to a paste', '8 garlic c...
# ...                                                  ...
# 13477  ['3 tablespoons white-wine vinegar', '2 tables...
# 13486  ['1/2 cup (1 stick) unsalted butter, room temp...
# 13492  ['1/2 cup (1 stick) unsalted European-style bu...
# 13493  ['4 tablespoons unsalted butter, melted', '1/3...
# 13499  ['1 stick (1/2 cup) plus 1 tablespoon unsalted...
#
#                                                    other
# 0      ['1 (3½–4-lb.) whole chicken', '2¾ tsp. kosher...
# 6      ['3 oz. Grand Marnier', '1 oz. Amaro Averna', ...
# 8      ['¾ cup assorted dals (such as chana dal, moon...
# ...

# %%
tree_census_subset = tree_census[['Title', 'Cleaned_Ingredients', 'Instructions','Image_Name']]
tree_census_subset
# Out:
#                                                    Title  \
# 0      Miso-Butter Roast Chicken With Acorn Squash Pa...
# 1                        Crispy Salt and Pepper Potatoes
# 2                            Thanksgiving Mac and Cheese
# 3                     Italian Sausage and Bread Stuffing
# 4                                           Newton's Law
# ...                                                  ...
# 13496                               Brownie Pudding Cake
# 13497  Israeli Couscous with Roasted Butternut Squash...
# 13498  Rice with Soy-Glazed Bonito Flakes and Sesame ...
# 13499                                        Spanakopita
# 13500  Mexican Poblano, Spinach, and Black Bean "Lasa...
#
#                                      Cleaned_Ingredients  \
# 0      ['1 (3½–4-lb.) whole chicken', '2¾ tsp. kosher...
# 1      ['2 large egg whites', '1 pound new potatoes (...
# 2      ['1 cup evaporated milk', '1 cup whole milk', ...
# ...

# %%
tree_census_subset.dtypes
# Out:
# Title                  object
# Cleaned_Ingredients    object
# Instructions           object
# Image_Name             object
# dtype: object

# %%
tree_census_subset.isna().sum()
# Out:
# Title                  5
# Cleaned_Ingredients    0
# Instructions           8
# Image_Name             0
# dtype: int64

# %%
tree_census_subset[tree_census_subset['Title'].isna()]
# Out:
#       Title Cleaned_Ingredients Instructions  \
# 11221   NaN                ['']          NaN
# 12373   NaN                ['']          NaN
# 12378   NaN                ['']          NaN
# 12818   NaN                ['']          NaN
# 12829   NaN                ['']          NaN
#
#                                               Image_Name
# 11221  roasted-game-hens-with-caramelized-root-vegeta...
# 12373                      chicken-soup-with-rice-232605
# 12378                           double-lemon-bars-232572
# 12818  pear-and-frangipane-crostata-with-raspberry-vi...
# 12829                  hazelnut-shortbread-sticks-231311

# %%
tree_census_subset.describe()
# Out:
#                 Title Cleaned_Ingredients  \
# count           13496               13501
# unique          13305               13473
# top     Potato Latkes                ['']
# freq                5                  12
#
#                                              Instructions Image_Name
# count                                               13493      13501
# unique                                              13464      13472
# top     Place ingredients in blender in the order list...     #NAME?
# freq                                                    5         30

# %%
tree_census_subset.dropna()
# Out:
#                                                    Title  \
# 0      Miso-Butter Roast Chicken With Acorn Squash Pa...
# 1                        Crispy Salt and Pepper Potatoes
# 2                            Thanksgiving Mac and Cheese
# 3                     Italian Sausage and Bread Stuffing
# 4                                           Newton's Law
# ...                                                  ...
# 13496                               Brownie Pudding Cake
# 13497  Israeli Couscous with Roasted Butternut Squash...
# 13498  Rice with Soy-Glazed Bonito Flakes and Sesame ...
# 13499                                        Spanakopita
# 13500  Mexican Poblano, Spinach, and Black Bean "Lasa...
#
#                                      Cleaned_Ingredients  \
# 0      ['1 (3½–4-lb.) whole chicken', '2¾ tsp. kosher...
# 1      ['2 large egg whites', '1 pound new potatoes (...
# 2      ['1 cup evaporated milk', '1 cup whole milk', ...
# ...

# %%
tree_census_subset = tree_census_subset.copy() # make a copy of the DataFrame
tree_census_subset.loc[:, 'Id'] = 'FR' + (tree_census_subset.index + 1).astype(str).str.zfill(6)
tree_census_subset['Views'] = 0
tree_census_subset = tree_census_subset [['Id','Title', 'Cleaned_Ingredients', 'Instructions','Image_Name','Views']]
tree_census_subset
# Out:
#              Id                                              Title  \
# 0      FR000001  Miso-Butter Roast Chicken With Acorn Squash Pa...
# 1      FR000002                    Crispy Salt and Pepper Potatoes
# 2      FR000003                        Thanksgiving Mac and Cheese
# 3      FR000004                 Italian Sausage and Bread Stuffing
# 4      FR000005                                       Newton's Law
# ...         ...                                                ...
# 13496  FR013497                               Brownie Pudding Cake
# 13497  FR013498  Israeli Couscous with Roasted Butternut Squash...
# 13498  FR013499  Rice with Soy-Glazed Bonito Flakes and Sesame ...
# 13499  FR013500                                        Spanakopita
# 13500  FR013501  Mexican Poblano, Spinach, and Black Bean "Lasa...
#
#                                      Cleaned_Ingredients  \
# 0      ['1 (3½–4-lb.) whole chicken', '2¾ tsp. kosher...
# ...

# %%
tree_census_subset.to_csv('Gusto Dataset - Cleaned.csv', index=False)
